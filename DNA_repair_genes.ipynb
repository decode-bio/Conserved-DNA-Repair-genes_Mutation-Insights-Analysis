# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now Coverting the TSV(Tab separated values) files into the CSV(Comma separated values) for further analysis

# %% [markdown]
# # PMS2 gene Mutaion analysis

# %%
pd.read_csv('Mutation_data_pms2.tsv', sep='\t').to_csv('Mutation_data_pms2.csv', index=False)
mut_data_pms2=pd.read_csv('Mutation_data_pms2.csv')

# %%
mut_data_pms2
# Out:
#      Gene                                    Study of Origin        Sample ID  \
# 0  PMS2CL  Lung Squamous Cell Carcinoma (TCGA, PanCancer ...  TCGA-18-3411-01
# 1  PMS2CL  Liver Hepatocellular Carcinoma (TCGA, PanCance...  TCGA-UB-A7MA-01
# 2  PMS2CL  Colorectal Adenocarcinoma (TCGA, PanCancer Atlas)  TCGA-A6-2686-01
#
#                   Cancer Type          Cancer Type Detailed Protein Change  \
# 0  Non-Small Cell Lung Cancer  Lung Squamous Cell Carcinoma    X405_splice
# 1        Hepatobiliary Cancer      Hepatocellular Carcinoma    X406_splice
# 2           Colorectal Cancer          Colon Adenocarcinoma    X372_splice
#
#                                           Annotation  Custom Driver  \
# 0  OncoKB: NA;CIViC: NA;MyCancerGenome: not prese...            NaN
# 1  OncoKB: NA;CIViC: NA;MyCancerGenome: not prese...            NaN
# 2  OncoKB: NA;CIViC: NA;MyCancerGenome: not prese...            NaN
#
# ...

# %% [markdown]
# # As we will not be using all the values in the given table we can ignore the null values as it will not affect out analysis

# %%
Cancer = mut_data_pms2['Cancer Type']
Frequency = mut_data_pms2['Allele Freq (T)']

# %%
plt.figure(figsize=(10,6))
plt.bar(Cancer, Frequency, color='skyblue', edgecolor='black')
plt.title('Cancer type vs. Allele frequency')
plt.xlabel('Cancer Type')
plt.ylabel('Allele Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
Cancer = mut_data_pms2['Cancer Type']
Mutaion = mut_data_pms2['# Mut in Sample']

# %%
plt.figure(figsize=(10,6))
plt.bar(Cancer, Mutaion, color='orange', edgecolor='black')
plt.title('Cancer type vs. Mutaions in PMS2 ')
plt.xlabel('Cancer Type')
plt.ylabel('Mutations')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Rad51c gene mutation Analysis

# %%
pd.read_csv('Mutation_data_rad51c.tsv', sep='\t').to_csv('Mutation_data_rad51c.csv', index=False)
mut_data_rad51c=pd.read_csv('Mutation_data_rad51c.csv')

# %%
mut_data_rad51c
# Out:
#       Gene                                    Study of Origin  \
# 0   RAD51C  Bladder Urothelial Carcinoma (TCGA, PanCancer ...
# 1   RAD51C  Bladder Urothelial Carcinoma (TCGA, PanCancer ...
# 2   RAD51C  Bladder Urothelial Carcinoma (TCGA, PanCancer ...
# 3   RAD51C  Breast Invasive Carcinoma (TCGA, PanCancer Atlas)
# 4   RAD51C  Breast Invasive Carcinoma (TCGA, PanCancer Atlas)
# ..     ...                                                ...
# 70  RAD51C  Head and Neck Squamous Cell Carcinoma (TCGA, P...
# 71  RAD51C  Cervical Squamous Cell Carcinoma (TCGA, PanCan...
# 72  RAD51C  Cervical Squamous Cell Carcinoma (TCGA, PanCan...
# 73  RAD51C  Cervical Squamous Cell Carcinoma (TCGA, PanCan...
# 74  RAD51C  Cervical Squamous Cell Carcinoma (TCGA, PanCan...
#
#           Sample ID           Cancer Type  \
# 0   TCGA-BT-A2LB-01        Bladder Cancer
# 1   TCGA-FD-A3N5-01        Bladder Cancer
# 2   TCGA-FD-A5BZ-01        Bladder Cancer
# 3   TCGA-BH-A209-01         Breast Cancer
# ...

# %%
Cancer2 = mut_data_rad51c['Cancer Type']
Frequency2 = mut_data_rad51c['Allele Freq (T)']

# %%
plt.figure(figsize=(14,6))
plt.bar(Cancer2, Frequency2, color='skyblue', edgecolor='black')
plt.title('Cancer type vs. Allele frequency for rad51c gene')
plt.xlabel('Cancer Type')
plt.ylabel('Allele Frequency')
plt.xticks(rotation=45, ha='right') 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
Cancer1 = mut_data_rad51c['Cancer Type']
Mutaion1 = mut_data_rad51c['# Mut in Sample']

# %%
plt.figure(figsize=(14,6))
plt.bar(Cancer1, Mutaion1, color='orange', edgecolor='black')
plt.title('Cancer type vs. Mutation for rad51c gene')
plt.xlabel('Cancer Type')
plt.ylabel('Mutation')
plt.xticks(rotation=45, ha='right') 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# lets to see in which cancer type the gene has mutated the most 
type_counts = mut_data_rad51c.groupby('Cancer Type').size()

# %%
plt.figure(figsize=(10,6))
type_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Cancer Type Occurrence per Sample for rad51c gene')
plt.xlabel(' Cancer Type')
plt.ylabel('Count')
plt.yticks(np.arange(0, 30, 2))
plt.xticks(rotation=45, ha = 'right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # xrcc1 gene Mutation Analysis

# %%
pd.read_csv('Mutation_data_xrcc1.tsv', sep='\t').to_csv('Mutation_data_xrcc1.csv', index=False)
mut_data_xrcc1=pd.read_csv('Mutation_data_xrcc1.csv')

# %%
mut_data_xrcc1
# Out:
#      Gene                                    Study of Origin        Sample ID  \
# 0   XRCC1  Ovarian Serous Cystadenocarcinoma (TCGA, PanCa...  TCGA-59-2349-01
# 1   XRCC1  Ovarian Serous Cystadenocarcinoma (TCGA, PanCa...  TCGA-23-1121-01
# 2   XRCC1  Ovarian Serous Cystadenocarcinoma (TCGA, PanCa...  TCGA-59-2349-01
# 3   XRCC1  Lung Squamous Cell Carcinoma (TCGA, PanCancer ...  TCGA-60-2723-01
# 4   XRCC1  Bladder Urothelial Carcinoma (TCGA, PanCancer ...  TCGA-MV-A51V-01
# ..    ...                                                ...              ...
# 93  XRCC1  Colorectal Adenocarcinoma (TCGA, PanCancer Atlas)  TCGA-D5-6927-01
# 94  XRCC1  Cervical Squamous Cell Carcinoma (TCGA, PanCan...  TCGA-Q1-A73O-01
# 95  XRCC1  Cervical Squamous Cell Carcinoma (TCGA, PanCan...  TCGA-IR-A3LA-01
# 96  XRCC1  Cervical Squamous Cell Carcinoma (TCGA, PanCan...  TCGA-2W-A8YY-01
# 97  XRCC1  Cervical Squamous Cell Carcinoma (TCGA, PanCan...  TCGA-UC-A7PI-01
#
# ...

# %%
Cancer3 = mut_data_xrcc1['Cancer Type']
Frequency3 = mut_data_xrcc1['Allele Freq (T)']

# %%
plt.figure(figsize=(14,6))
plt.bar(Cancer3, Frequency3, color='skyblue', edgecolor='black')
plt.title('Cancer type vs. Allele frequency for xrcc1 gene')
plt.xlabel('Cancer Type')
plt.ylabel('Allele Frequency')
plt.xticks(rotation=45, ha='right') 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
Cancer3 = mut_data_xrcc1['Cancer Type']
Mutaion3 = mut_data_xrcc1['# Mut in Sample']

# %%
plt.figure(figsize=(14,6))
plt.bar(Cancer3, Mutaion3, color='orange', edgecolor='black')
plt.title('Cancer type vs. Mutation for xrcc1 gene')
plt.xlabel('Cancer Type')
plt.ylabel('Mutation')
plt.xticks(rotation=45, ha='right') 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# lets to see in which cancer type the gene has mutated the most 
type_counts2 = mut_data_xrcc1.groupby('Cancer Type').size()

# %%
plt.figure(figsize=(10,6))
type_counts2.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Cancer Type Occurrence per Sample in xrcc1 gene')
plt.xlabel(' Cancer Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha = 'right')
plt.yticks(np.arange(0, 30, 2))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
